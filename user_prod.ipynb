# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from itertools import combinations as c
from plotly.offline import init_notebook_mode, iplot
from plotly.graph_objs import*
import plotly.graph_objects as go
import plotly
import dash
#import chart_studio.tools as tls
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px
from flask import Flask, render_template

# %%
df = pd.read_csv("User Productivity Summary.csv")

# %%
df.head()
# Out:
#    siteid  subsiteid                i3user  \
# 0       2          0  angelicamae.bartolay
# 1       2          0  angelicamae.bartolay
# 2       2          0         bhea.celebran
# 3       2          0         bhea.celebran
# 4       2          0     cecilia.morales01
#
#                                   queue  totEnteredACD  totnAnswered  \
# 0                                     -              0             1
# 1  PH_Kinray_CustomerService_Z1_English            275           381
# 2                                     -              0             0
# 3  PH_Kinray_CustomerService_Z1_English            228           345
# 4                                     -              0             6
#
#    totnAnsweredACD  totnAbandonedACD  totnFlowOutAcd  totnTransferedACD  ...  \
# 0                0                 0               0                  0  ...
# 1              267                 4               4                  3  ...
# 2                0                 0               0                  0  ...
# 3              226                 1               1                  5  ...
# 4                0                 0               0                  0  ...
#
#                   IndivID  LastName     FirstName  MiddleName  \
# 0  4cl<xtr,((e~3mz*b?p$-3  Bartolay  Angelica Mae
# 1  4cl<xtr,((e~3mz*b?p$-3  Bartolay  Angelica Mae
# 2  *[`o&bw+^x;zd{-sw{)7`3  celebran          Bhea
# 3  *[`o&bw+^x;zd{-sw{)7`3  celebran          Bhea
# 4  0ys78|i!&lim8m?},0[?{2   Morales       Cecilia
#
#          DisplayUserName                      JobTitle              ICUserID  \
# 0  Angelica Mae Bartolay  Rep II, Customer Service Ops  angelicamae.bartolay
# 1  Angelica Mae Bartolay  Rep II, Customer Service Ops  angelicamae.bartolay
# 2          Bhea celebran                                       bhea.celebran
# 3          Bhea celebran                                       bhea.celebran
# 4        Cecilia Morales  Sr Rep, Customer Service Ops     cecilia.morales01
#
#    ExtID  ExtSource  rank
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
#
# [5 rows x 38 columns]

# %%
df["userid"] = df["FirstName"] + " " +  df["LastName"]

# %%
#df = df.pivot_table(index = ["userid"])
df = df.groupby(['userid','queue'], as_index = True).sum()

# %%
df.head()
# Out:
#                                                             siteid  subsiteid  \
# userid                queue
# Angelica Mae Bartolay -                                          2          0
#                       PH_Kinray_CustomerService_Z1_English       2          0
# Bhea celebran         -                                          2          0
#                       PH_Kinray_CustomerService_Z1_English       2          0
# Cecilia Morales       -                                          2          0
#
#                                                             totEnteredACD  \
# userid                queue
# Angelica Mae Bartolay -                                                 0
#                       PH_Kinray_CustomerService_Z1_English            275
# Bhea celebran         -                                                 0
#                       PH_Kinray_CustomerService_Z1_English            228
# Cecilia Morales       -                                                 0
#
#                                                             totnAnswered  \
# userid                queue
# Angelica Mae Bartolay -                                                1
#                       PH_Kinray_CustomerService_Z1_English           381
# Bhea celebran         -                                                0
#                       PH_Kinray_CustomerService_Z1_English           345
# Cecilia Morales       -                                                6
#
#                                                             totnAnsweredACD  \
# userid                queue
# Angelica Mae Bartolay -                                                   0
#                       PH_Kinray_CustomerService_Z1_English              267
# Bhea celebran         -                                                   0
#                       PH_Kinray_CustomerService_Z1_English              226
# Cecilia Morales       -                                                   0
#
#                                                             totnAbandonedACD  \
# userid                queue
# Angelica Mae Bartolay -                                                    0
#                       PH_Kinray_CustomerService_Z1_English                 4
# Bhea celebran         -                                                    0
#                       PH_Kinray_CustomerService_Z1_English                 1
# Cecilia Morales       -                                                    0
#
#                                                             totnFlowOutAcd  \
# userid                queue
# Angelica Mae Bartolay -                                                  0
#                       PH_Kinray_CustomerService_Z1_English               4
# Bhea celebran         -                                                  0
#                       PH_Kinray_CustomerService_Z1_English               1
# Cecilia Morales       -                                                  0
#
#                                                             totnTransferedACD  \
# userid                queue
# Angelica Mae Bartolay -                                                     0
#                       PH_Kinray_CustomerService_Z1_English                  3
# Bhea celebran         -                                                     0
#                       PH_Kinray_CustomerService_Z1_English                  5
# Cecilia Morales       -                                                     0
#
#                                                             totnIntToIntACD  \
# userid                queue
# Angelica Mae Bartolay -                                                   0
#                       PH_Kinray_CustomerService_Z1_English                0
# Bhea celebran         -                                                   0
#                       PH_Kinray_CustomerService_Z1_English                0
# Cecilia Morales       -                                                   0
#
#                                                             totnExtToInt  ...  \
# userid                queue                                               ...
# Angelica Mae Bartolay -                                                0  ...
#                       PH_Kinray_CustomerService_Z1_English           271  ...
# Bhea celebran         -                                                0  ...
#                       PH_Kinray_CustomerService_Z1_English           227  ...
# Cecilia Morales       -                                                9  ...
#
#                                                             totTAgentACDLoggedIn  \
# userid                queue
# Angelica Mae Bartolay -                                                        0
#                       PH_Kinray_CustomerService_Z1_English                     0
# Bhea celebran         -                                                        0
#                       PH_Kinray_CustomerService_Z1_English                     0
# Cecilia Morales       -                                                        0
#
#                                                             totnExttoIntNONACD  \
# userid                queue
# Angelica Mae Bartolay -                                                      0
#                       PH_Kinray_CustomerService_Z1_English                   0
# Bhea celebran         -                                                      0
#                       PH_Kinray_CustomerService_Z1_English                   0
# Cecilia Morales       -                                                      9
#
#                                                             totnInttoExtNONACD  \
# userid                queue
# Angelica Mae Bartolay -                                                      0
#                       PH_Kinray_CustomerService_Z1_English                 114
# Bhea celebran         -                                                      0
#                       PH_Kinray_CustomerService_Z1_English                 116
# Cecilia Morales       -                                                      0
#
#                                                             totTExttoIntNONACD  \
# userid                queue
# Angelica Mae Bartolay -                                                      0
#                       PH_Kinray_CustomerService_Z1_English                   0
# Bhea celebran         -                                                      0
#                       PH_Kinray_CustomerService_Z1_English                   0
# Cecilia Morales       -                                                   1035
#
#                                                             totTInttoExtNONACD  \
# userid                queue
# Angelica Mae Bartolay -                                                      0
#                       PH_Kinray_CustomerService_Z1_English               17711
# Bhea celebran         -                                                      0
#                       PH_Kinray_CustomerService_Z1_English               19555
# Cecilia Morales       -                                                      0
#
#                                                             Active  IsPrivate  \
# userid                queue
# Angelica Mae Bartolay -                                          1          0
#                       PH_Kinray_CustomerService_Z1_English       1          0
# Bhea celebran         -                                          1          0
#                       PH_Kinray_CustomerService_Z1_English       1          0
# Cecilia Morales       -                                          1          0
#
#                                                             IndivTypeID  \
# userid                queue
# Angelica Mae Bartolay -                                               2
#                       PH_Kinray_CustomerService_Z1_English            2
# Bhea celebran         -                                               2
#                       PH_Kinray_CustomerService_Z1_English            2
# Cecilia Morales       -                                               2
#
#                                                             TitleID  rank
# userid                queue
# Angelica Mae Bartolay -                                         0.0     1
#                       PH_Kinray_CustomerService_Z1_English      0.0     1
# Bhea celebran         -                                         0.0     1
#                       PH_Kinray_CustomerService_Z1_English      0.0     1
# Cecilia Morales       -                                         0.0     1
#
# [5 rows x 27 columns]

# %%
print(df.columns)
# Out:
# Index(['siteid', 'subsiteid', 'totEnteredACD', 'totnAnswered',
#        'totnAnsweredACD', 'totnAbandonedACD', 'totnFlowOutAcd',
#        'totnTransferedACD', 'totnIntToIntACD', 'totnExtToInt', 'totnIntToExt',
#        'totTTalkACD', 'totTACW', 'totTHoldACD', 'totTAgentLoggedin',
#        'totTAgentLoggedin2', 'totTAgentAvailable', 'totTAgentACDLoggedIn',
#        'totnExttoIntNONACD', 'totnInttoExtNONACD', 'totTExttoIntNONACD',
#        'totTInttoExtNONACD', 'Active', 'IsPrivate', 'IndivTypeID', 'TitleID',
#        'rank'],
#       dtype='object')

# %%
df = df.reset_index(level=0)
#df = df.reset_index(level=0)

# %%
# Out:
# array([['Angelica Mae Bartolay', 2, 0, ..., 2, 0.0, 1],
#        ['Angelica Mae Bartolay', 2, 0, ..., 2, 0.0, 1],
#        ['Bhea celebran', 2, 0, ..., 2, 0.0, 1],
#        ...,
#        ['Tawanda Richards', 2, 0, ..., 2, 0.0, 1],
#        ['Yeszenia Mendoza', 2, 0, ..., 2, 0.0, 1],
#        ['Yeszenia Mendoza', 2, 0, ..., 2, 0.0, 1]], dtype=object)

# %%
df = df[df['queue'] == "PH_Kinray_CustomerService_Z1_English"]
df= df[df['totnAnsweredACD'] > 0]
df.head()
# Out:
#     siteid  subsiteid                i3user  \
# 1        2          0  angelicamae.bartolay
# 3        2          0         bhea.celebran
# 5        2          0     cecilia.morales01
# 10       2          0         dina.townsend
# 12       2          0    fatimagrace.antham
#
#                                    queue  totEnteredACD  totnAnswered  \
# 1   PH_Kinray_CustomerService_Z1_English            275           381
# 3   PH_Kinray_CustomerService_Z1_English            228           345
# 5   PH_Kinray_CustomerService_Z1_English            349           514
# 10  PH_Kinray_CustomerService_Z1_English            363           355
# 12  PH_Kinray_CustomerService_Z1_English            363           347
#
#     totnAnsweredACD  totnAbandonedACD  totnFlowOutAcd  totnTransferedACD  ...  \
# 1               267                 4               4                  3  ...
# 3               226                 1               1                  5  ...
# 5               339                 0              10                 20  ...
# 10              355                 1               7                 14  ...
# 12              347                 2              14                  9  ...
#
#     LastName     FirstName  MiddleName        DisplayUserName  \
# 1   Bartolay  Angelica Mae              Angelica Mae Bartolay
# 3   celebran          Bhea                      Bhea celebran
# 5    Morales       Cecilia                    Cecilia Morales
# 10  Townsend          Dina                      Dina Townsend
# 12    Antham  Fatima Grace                Fatima Grace Antham
#
#                         JobTitle              ICUserID  ExtID  ExtSource  \
# 1   Rep II, Customer Service Ops  angelicamae.bartolay
# 3                                        bhea.celebran
# 5   Sr Rep, Customer Service Ops     cecilia.morales01
# 10  Rep II, Customer Service Ops         dina.townsend
# 12  Rep II, Customer Service Ops    fatimagrace.antham
#
#     rank                 userid
# 1      1  Angelica Mae Bartolay
# 3      1          Bhea celebran
# 5      1        Cecilia Morales
# 10     1          Dina Townsend
# 12     1    Fatima Grace Antham
#
# [5 rows x 39 columns]

# %%
df['acw'] = df["totTACW"] / df["totnAnsweredACD"] 
df['aht'] = (df[["totTACW", "totTTalkACD", "totTHoldACD"]].sum(axis = 1)) / df["totnAnsweredACD"]

# %%
acd = df[["userid","totnAnsweredACD","acw","aht"]]

# %%
print(acd.columns)
# Out:
# Index(['userid', 'totnAnsweredACD', 'acw', 'aht'], dtype='object')

# %%
acd.
# Out:
# <bound method DataFrame.items of                     userid  totnAnsweredACD         acw          aht
# 1    Angelica Mae Bartolay              267  190.936330   696.947566
# 3            Bhea celebran              226  681.721239  1599.128319
# 5          Cecilia Morales              339   71.017699   397.828909
# 10           Dina Townsend              355  502.898592   855.216901
# 12     Fatima Grace Antham              347  106.659942   639.907781
# 15      Genevieve Espinosa                3    0.000000   205.333333
# 20        Kamilah Williams              167  660.724551  1093.389222
# 22        Katherine Jaquez              275  196.472727   576.054545
# 24        Kristine Gillego              200   14.065000  1289.420000
# 26            Krystle Bush              229  669.117904  1217.401747
# 28    Marlene Pena-Worters              409  251.303178   643.508557
# 30        Michelle Bulloss              213  143.300469   739.807512
# 32           Nikol Presley              233  585.896996  1156.369099
# 34      Raven DeVane-Crews              393  241.480916   889.781170
# 36  Sharay Bryant robinson              216  833.217593  1210.921296
# 38          Sherly Mahtani              234  241.115385   907.679487
# 40        Tawanda Richards              313  374.920128   861.753994
# 42        Yeszenia Mendoza              230  878.386957  1450.034783>

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
sample = pd.DataFrame(data=[acd['userid'],df['userid']])

# %%
sample
# Out:
#                     userid
# 1    Angelica Mae Bartolay
# 3            Bhea celebran
# 5          Cecilia Morales
# 10           Dina Townsend
# 12     Fatima Grace Antham
# 15      Genevieve Espinosa
# 20        Kamilah Williams
# 22        Katherine Jaquez
# 24        Kristine Gillego
# 26            Krystle Bush
# 28    Marlene Pena-Worters
# 30        Michelle Bulloss
# 32           Nikol Presley
# 34      Raven DeVane-Crews
# 36  Sharay Bryant robinson
# 38          Sherly Mahtani
# 40        Tawanda Richards
# 42        Yeszenia Mendoza
